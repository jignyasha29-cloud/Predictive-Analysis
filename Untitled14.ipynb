# %% [markdown]
# <a href="https://colab.research.google.com/github/jignyasha29-cloud/Predictive-Analysis/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Step 1: Data Loading (Python)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Step 2: Data Understanding**

# %%
import pandas as pd

df = pd.read_csv("/amazon_ecommerce_1M.csv")
df.head()
# Out:
# /tmp/ipykernel_10031/4105459363.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/amazon_ecommerce_1M.csv")
#    user_id product_id     category subcategory    brand     price  discount  \
# 0  U356787     P39256  Electronics      Mobile      H&M  33090.51     10.46
# 1  U198246     P38657       Sports     Outdoor  Samsung   9368.97      5.32
# 2  U539898     P38893       Sports     Fitness      H&M  14756.85     26.00
# 3  U325772     P54118       Beauty      Makeup     Sony    668.83     24.81
# 4  U865179     P70217         Home       Decor     Sony  10881.29     48.63
#
#    final_price  rating  review_count  stock seller_id  seller_rating  \
# 0     29629.31     4.9          43.0   71.0     S2679            4.3
# 1      8870.73     3.9          13.0  119.0     S9279            4.9
# 2     10919.43     4.2          46.0  229.0     S5557            4.9
# ...

# %% [markdown]
# # **Step 3: Handling Missing Values**

# %%
df.shape
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699879 entries, 0 to 699878
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   user_id             699879 non-null  object
#  1   product_id          699879 non-null  object
#  2   category            699879 non-null  object
#  3   subcategory         699879 non-null  object
#  4   brand               699879 non-null  object
#  5   price               699879 non-null  float64
#  6   discount            699879 non-null  float64
#  7   final_price         699879 non-null  float64
#  8   rating              699879 non-null  float64
#  9   review_count        699878 non-null  float64
#  10  stock               699878 non-null  float64
#  11  seller_id           699878 non-null  object
#  12  seller_rating       699878 non-null  float64
#  13  purchase_date       699878 non-null  object
#  14  shipping_time_days  699878 non-null  float64
# ...

# %% [markdown]
# # **Step 3: Handling Missing Values**

# %%
df.isnull().sum()

# Example handling (adjust based on your columns)
df.fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_10031/1431704288.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10031/1431704288.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(method='ffill', inplace=True)

# %% [markdown]
# # **Step 4: Data Cleaning**

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # **Step 5: Data Visualization**

# %% [markdown]
# ***Price Distribution***

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['price'], kde=True)
plt.show()

# %% [markdown]
# ***Ratings Distribution***

# %%
sns.countplot(x='rating', data=df)
plt.show()

# %% [markdown]
# ***Category-wise Products***

# %%
df['category'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ***Correlation Analysis***

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
